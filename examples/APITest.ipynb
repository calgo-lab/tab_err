# %% [markdown]
# # Test of APIs

# %% [markdown]
# ### High Level API

# %%
from __future__ import annotations

import pandas as pd

from tab_err import ErrorModel, error_mechanism, error_type
from tab_err.api import MidLevelConfig, high_level, mid_level

df_typist_book_title = pd.DataFrame(
    {
        "typist": ["Alice", "Alice", "Alice", "Bob", "Bob", "Bob"],
        "book_title": ["To Kill a Mockingbird", "1984", "Pride and Prejudice", "The Great Gatsby", "Moby-Dick", "The Catcher in the Rye"],
        "rating": [1.0, 3.0, 3.0, 4.0, 2.0, 1.0],
    }
)

corrupted_data, error_mask = high_level.create_errors(df_typist_book_title, overall_max_error=0.75)
# Out:
# MidLevelConfig(columns={'rating': [ErrorModel(error_mechanism=<tab_err.error_mechanism._enar.ENAR object at 0x7f3cb34943d0>, error_type=<tab_err.error_type._missing.MissingValue object at 0x7f3cb34946a0>, error_rate=0.75)]})
# {'rating': [ErrorModel(error_mechanism=<tab_err.error_mechanism._enar.ENAR object at 0x7f3cb34943d0>, error_type=<tab_err.error_type._missing.MissingValue object at 0x7f3cb34946a0>, error_rate=0.75)]}

# %%
def show_result(original_df: pd.DataFrame, perturbed_df: pd.DataFrame, error_mask: pd.DataFrame | None = None) -> pd.DataFrame:
    """Simple helper function to show DataFrames after perturbing them."""
    return (
        pd.concat([original_df, perturbed_df], keys=["original", "perturbed"], axis=1)
        if error_mask is None
        else pd.concat([original_df, perturbed_df, error_mask], keys=["original", "perturbed", "error_mask"], axis=1)
    )

# %%
show_result(df_typist_book_title, corrupted_data, error_mask)
# Out:
#   original                                perturbed                       \
#     typist              book_title rating    typist           book_title
# 0    Alice   To Kill a Mockingbird    1.0     Alice                 None
# 1    Alice                    1984    3.0     Alice                 1984
# 2    Alice     Pride and Prejudice    3.0     Alice  Pride and Prejudice
# 3      Bob        The Great Gatsby    4.0       Bob                 None
# 4      Bob               Moby-Dick    2.0       Bob                 None
# 5      Bob  The Catcher in the Rye    1.0       Bob                 None
#
#          error_mask
#   rating     typist book_title rating
# 0    NaN      False       True   True
# 1    NaN      False      False   True
# 2    3.0      False      False  False
# 3    NaN      False       True   True
# 4    NaN      False       True   True
# 5    1.0      False       True  False

# %% [markdown]
# high-level config from yaml

# %%
corrupted_data, error_mask = high_level.create_errors_from_config(df_typist_book_title, "./../tab_err/hla_test_conf.yaml")
# Out:
# Mech:  EAR conditions:  {'conditioning-column': 'rating'}
# Mech:  ENAR conditions:  None
# None
# {'extraneous_value_template': '.{value}'}
# Mech:  EAR conditions:  {'conditioning-column': 'book_title'}
# None
# {'add_delta_value': 1.0}
# Mechanisms:  {'typist': [<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264d60>, <tab_err.error_mechanism._enar.ENAR object at 0x7f3ce8264d30>], 'rating': [<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264dc0>]}
# Types:  {'typist': [<tab_err.error_type._missing.MissingValue object at 0x7f3ce8265420>, <tab_err.error_type._extraneous.Extraneous object at 0x7f3ce8264be0>], 'rating': [<tab_err.error_type._missing.MissingValue object at 0x7f3ce82654e0>, <tab_err.error_type._add_delta.AddDelta object at 0x7f3cb2e0c3a0>]}
# Error Rates:  {'typist': [0.23291952890998147, 0.17383622383701464, 0.0932442472530039], 'rating': [0.4959253432423444, 0.40407465675765564]}
# Num Models:  {'typist': 3, 'rating': 2}
# Columns:  {'typist', 'rating'}
# Mid Level Config:  MidLevelConfig(columns={'typist': [ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264d60>, error_type=<tab_err.error_type._extraneous.Extraneous object at 0x7f3ce8264be0>, error_rate=0.23291952890998147), ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264d60>, error_type=<tab_err.error_type._missing.MissingValue object at 0x7f3ce8265420>, error_rate=0.17383622383701464), ErrorModel(error_mechanism=<tab_err.error_mechanism._enar.ENAR object at 0x7f3ce8264d30>, error_type=<tab_err.error_type._missing.MissingValue object at 0x7f3ce8265420>, error_rate=0.0932442472530039)], 'rating': [ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264dc0>, error_type=<tab_err.error_type._add_delta.AddDelta object at 0x7f3cb2e0c3a0>, error_rate=0.4959253432423444), ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264dc0>, error_type=<tab_err.error_type._add_delta.AddDelta object at 0x7f3cb2e0c3a0>, error_rate=0.40407465675765564)]})
# {'typist': [ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264d60>, error_type=<tab_err.error_type._extraneous.Extraneous object at 0x7f3ce8264be0>, error_rate=0.23291952890998147), ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264d60>, error_type=<tab_err.error_type._missing.MissingValue object at 0x7f3ce8265420>, error_rate=0.17383622383701464), ErrorModel(error_mechanism=<tab_err.error_mechanism._enar.ENAR object at 0x7f3ce8264d30>, error_type=<tab_err.error_type._missing.MissingValue object at 0x7f3ce8265420>, error_rate=0.0932442472530039)], 'rating': [ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264dc0>, error_type=<tab_err.error_type._add_delta.AddDelta object at 0x7f3cb2e0c3a0>, error_rate=0.4959253432423444), ErrorModel(error_mechanism=<tab_err.error_mechanism._ear.EAR object at 0x7f3ce8264dc0>, error_type=<tab_err.error_type._add_delta.AddDelta object at 0x7f3cb2e0c3a0>, error_rate=0.40407465675765564)]}
# typist
# <class 'str'>

# %%
show_result(df_typist_book_title, corrupted_data, error_mask)
# Out:
#   original                                perturbed                          \
#     typist              book_title rating    typist              book_title
# 0    Alice   To Kill a Mockingbird    1.0    .Alice   To Kill a Mockingbird
# 1    Alice                    1984    3.0     Alice                    1984
# 2    Alice     Pride and Prejudice    3.0      None     Pride and Prejudice
# 3      Bob        The Great Gatsby    4.0       Bob        The Great Gatsby
# 4      Bob               Moby-Dick    2.0       Bob               Moby-Dick
# 5      Bob  The Catcher in the Rye    1.0       Bob  The Catcher in the Rye
#
#          error_mask
#   rating     typist book_title rating
# 0    1.0       True      False  False
# 1    4.0      False      False   True
# 2    3.0       True      False  False
# 3    5.0      False      False   True
# 4    3.0      False      False   True
# 5    2.0      False      False   True

# %% [markdown]
# Mid level api test -- ground truth -- And there's an indexer error...

# %%
conf = MidLevelConfig(
    {
        "rating": [
            ErrorModel(
                error_mechanism=error_mechanism.ECAR(),
                error_type=error_type.WrongUnit({"wrong_unit_scaling": {lambda x: x*10}}),
                error_rate=0.5
            )
        ]
    }
)
corrupted_data, error_mask = mid_level.create_errors(df_typist_book_title, conf)
show_result(df_typist_book_title, corrupted_data, error_mask)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 12
#       1 conf = MidLevelConfig(
#       2     {
#       3         "rating": [
#    (...)
#      10     }
#      11 )
# ---> 12 corrupted_data, error_mask = mid_level.create_errors(df_typist_book_title, conf)
#      13 show_result(df_typist_book_title, corrupted_data, error_mask)
#
# File /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/mid_level.py:72, in create_errors(data, config)
#      69         old_error_mask = error_mask.copy()
#      70         error_mask = error_mechanism.sample(data, column, error_rate, error_mask)
# ---> 72         series = error_type.apply(data_dirty, old_error_mask != error_mask, column)
#      73         set_column(data_dirty, column, series)
#      75 return data_dirty, error_mask
#
# File /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:70, in ErrorType.apply(self, data, error_mask, column)
#      67     raise ValueError(msg)
#      69 self._random_generator = seed_randomness(self._seed)
# ---> 70 return self._apply(data, error_mask, column)
#
# File /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_wrong_unit.py:47, in WrongUnit._apply(self, data, error_mask, column)
#      44 series = get_column(data, column).astype("object").copy()
#      45 series_mask = get_column(error_mask, column)
# ---> 47 series.loc[series_mask] = series.loc[series_mask].apply(self.config.wrong_unit_scaling)
#      48 return series
#
# File ~/.cache/pypoetry/virtualenvs/tab-err-3BZUcCcg-py3.10/lib/python3.10/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/.cache/pypoetry/virtualenvs/tab-err-3BZUcCcg-py3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1944, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
# -> 1944     self._setitem_single_block(indexer, value, name)
#
# File ~/.cache/pypoetry/virtualenvs/tab-err-3BZUcCcg-py3.10/lib/python3.10/site-packages/pandas/core/indexing.py:2212, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    2209     indexer = maybe_convert_ix(*indexer)  # e.g. test_setitem_frame_align
#    2211 if isinstance(value, ABCDataFrame) and name != "iloc":
# -> 2212     value = self._align_frame(indexer, value)._values
#    2214 # check for chained assignment
#    2215 self.obj._check_is_chained_assignment_possible()
#
# File ~/.cache/pypoetry/virtualenvs/tab-err-3BZUcCcg-py3.10/lib/python3.10/site-packages/pandas/core/indexing.py:2504, in _iLocIndexer._align_frame(self, indexer, df)
#    2501         val = df.reindex(index=ax)
#    2502     return val
# -> 2504 raise ValueError("Incompatible indexer with DataFrame")
#
# ValueError: Incompatible indexer with DataFrame
