# %% [markdown]
# # Test of the High-Level API
#
# For development purposes

# %%
# %load_ext autoreload
# %autoreload 2
from __future__ import annotations

import pandas as pd

from tab_err import error_type, error_mechanism
from tab_err.api import high_level
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def show_result(original_df: pd.DataFrame, perturbed_df: pd.DataFrame, error_mask: pd.DataFrame | None = None) -> pd.DataFrame:
    """Simple helper function to show DataFrames after perturbing them."""
    return (
        pd.concat([original_df, perturbed_df], keys=["original", "perturbed"], axis=1)
        if error_mask is None
        else pd.concat([original_df, perturbed_df, error_mask], keys=["original", "perturbed", "error_mask"], axis=1)
    )

# %%
df_typist_book_title = pd.DataFrame(
    {
        "typist": ["Alice", "Alice", "Alice", "Bob", "Bob", "Bob"],
        "book_title": ["To Kill a Mockingbird", "1984", "Pride and Prejudice", "The Great Gatsby", "Moby-Dick", "The Catcher in the Rye"],
        "rating": [1.0, 3.0, 3.0, 4.0, 2.0, 1.0],
    }
)



print(df_typist_book_title.dtypes)
# Out:
# typist         object
# book_title     object
# rating        float64
# dtype: object

# %% [markdown]
# ### TEST

# %%
df_corrupted, error_mask = high_level.create_errors(df_typist_book_title, 0.5)
show_result(df_typist_book_title, df_corrupted, error_mask)
# Out:
# Column-type dict:  {'typist': [<tab_err.error_type._extraneous.Extraneous object at 0x7f99299ca4a0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f99299cae60>, <tab_err.error_type._replace.Replace object at 0x7f99299ca200>, <tab_err.error_type._typo.Typo object at 0x7f99299cada0>, <tab_err.error_type._missing.MissingValue object at 0x7f99299cad40>], 'book_title': [<tab_err.error_type._extraneous.Extraneous object at 0x7f99299ca4a0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f99299cae60>, <tab_err.error_type._replace.Replace object at 0x7f99299ca200>, <tab_err.error_type._typo.Typo object at 0x7f99299cada0>, <tab_err.error_type._missing.MissingValue object at 0x7f99299cad40>], 'rating': [<tab_err.error_type._add_delta.AddDelta object at 0x7f99299ca350>, <tab_err.error_type._outlier.Outlier object at 0x7f99299cb970>, <tab_err.error_type._wrong_unit.WrongUnit object at 0x7f99299cbac0>, <tab_err.error_type._missing.MissingValue object at 0x7f99299cad40>]}
# Column-mech dict:  {'typist': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299c9ae0>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc70>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f4f400>, <tab_err.error_mechanism._ear.EAR object at 0x7f9929471600>], 'book_title': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299c9ae0>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc70>, <tab_err.error_mechanism._ear.EAR object at 0x7f992981d630>, <tab_err.error_mechanism._ear.EAR object at 0x7f9929470df0>], 'rating': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299c9ae0>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc70>, <tab_err.error_mechanism._ear.EAR object at 0x7f99292730a0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99294713f0>]}
# Column-num_models dict:  {'typist': 20, 'book_title': 20, 'rating': 16}
# Column-error_rates dict:  {'typist': 0.025, 'book_title': 0.025, 'rating': 0.03125}
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/high_level.py:199: UserWarning: With an error rate for the column (typist) of: 0.025 and a length of: 6, 0 errors will be introduced.
#   # Build MidLevel Config
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/high_level.py:199: UserWarning: With an error rate for the column (book_title) of: 0.025 and a length of: 6, 0 errors will be introduced.
#   # Build MidLevel Config
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/high_level.py:199: UserWarning: With an error rate for the column (rating) of: 0.03125 and a length of: 6, 0 errors will be introduced.
#   # Build MidLevel Config
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.extraneous_value_template is not set. Choosing a random string augmentation.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: The 'replace_what' parameter is not configured, defaulting to a random character from the given series. Replacements are not guaranteed.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.add_delta_value is none, sampling a random delta value uniformly from the range of column: rating.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: No scaling function was supplied for WrongUnit, defaulting to multiplication by 10.0.
#   return self._apply(data, error_mask, column)
#   original                                 ... error_mask
#     typist              book_title rating  ...     typist book_title rating
# 0    Alice   To Kill a Mockingbird    1.0  ...      False      False  False
# 1    Alice                    1984    3.0  ...      False      False  False
# 2    Alice     Pride and Prejudice    3.0  ...      False      False  False
# 3      Bob        The Great Gatsby    4.0  ...      False      False  False
# 4      Bob               Moby-Dick    2.0  ...      False      False  False
# 5      Bob  The Catcher in the Rye    1.0  ...      False      False  False
#
# [6 rows x 9 columns]

# %% [markdown]
# # Testing of High Level API with a large dataset

# %%
# Read in data
df_clean = pd.read_csv("./clean_beers.csv")
df_clean.head()
# Out:
#    index    id            beer_name  ...               brewery_name  city  state
# 0      1  1436             Pub Beer  ...  10 Barrel Brewing Company  Bend     OR
# 1      2  2265          Devil's Cup  ...        18th Street Brewery  Gary     IN
# 2      3  2264  Rise of the Phoenix  ...        18th Street Brewery  Gary     IN
# 3      4  2263             Sinister  ...        18th Street Brewery  Gary     IN
# 4      5  2262        Sex and Candy  ...        18th Street Brewery  Gary     IN
#
# [5 rows x 11 columns]

# %%
df_clean = df_clean.drop(columns = ["index", "id", "ounces", "ibu", "brewery_id", "city"])
df_clean.head()
# Out:
#              beer_name  ... state
# 0             Pub Beer  ...    OR
# 1          Devil's Cup  ...    IN
# 2  Rise of the Phoenix  ...    IN
# 3             Sinister  ...    IN
# 4        Sex and Candy  ...    IN
#
# [5 rows x 5 columns]

# %%
# Add a date time column, just all the same date
df_clean["arbitrary_date"] = pd.to_datetime("2025-02-20 14:30:00")
df_clean.head()
# Out:
#              beer_name  ...      arbitrary_date
# 0             Pub Beer  ... 2025-02-20 14:30:00
# 1          Devil's Cup  ... 2025-02-20 14:30:00
# 2  Rise of the Phoenix  ... 2025-02-20 14:30:00
# 3             Sinister  ... 2025-02-20 14:30:00
# 4        Sex and Candy  ... 2025-02-20 14:30:00
#
# [5 rows x 6 columns]

# %%
df_clean["beer_name"] = df_clean["beer_name"].astype(str)
df_clean["style"] = df_clean["style"].astype(str)
df_clean["brewery_name"] = df_clean["brewery_name"].astype(str)
df_clean["state"] = df_clean["state"].astype(str)
df_clean.dtypes
# Out:
# beer_name                 object
# style                     object
# abv                      float64
# brewery_name              object
# state                     object
# arbitrary_date    datetime64[ns]
# dtype: object

# %%
# No error type spec
df_dirty, error_mask = high_level.create_errors(df_clean, max_error_rate=0.75)
show_result(df_clean, df_dirty, error_mask)
# Out:
# Column-type dict:  {'beer_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8ef50>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8fd90>, <tab_err.error_type._replace.Replace object at 0x7f9928f8fc70>, <tab_err.error_type._typo.Typo object at 0x7f9928f8f280>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8f790>], 'style': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8ef50>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8fd90>, <tab_err.error_type._replace.Replace object at 0x7f9928f8fc70>, <tab_err.error_type._typo.Typo object at 0x7f9928f8f280>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8f790>], 'abv': [<tab_err.error_type._add_delta.AddDelta object at 0x7f9928f8d180>, <tab_err.error_type._outlier.Outlier object at 0x7f9928f8e230>, <tab_err.error_type._wrong_unit.WrongUnit object at 0x7f9928f8ef80>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8f790>], 'brewery_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8ef50>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8fd90>, <tab_err.error_type._replace.Replace object at 0x7f9928f8fc70>, <tab_err.error_type._typo.Typo object at 0x7f9928f8f280>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8f790>], 'state': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8ef50>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8fd90>, <tab_err.error_type._replace.Replace object at 0x7f9928f8fc70>, <tab_err.error_type._typo.Typo object at 0x7f9928f8f280>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8f790>], 'arbitrary_date': [<tab_err.error_type._add_delta.AddDelta object at 0x7f9928f8d180>, <tab_err.error_type._outlier.Outlier object at 0x7f9928f8e230>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8f790>]}
# Column-mech dict:  {'beer_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8d720>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8ec80>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f8b0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e260>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8c460>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8d780>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f6a0>], 'style': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8d720>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8ec80>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f370>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8ee90>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8d090>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8efb0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8eb60>], 'abv': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8d720>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8ec80>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e290>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e2c0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f310>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8cdf0>, <tab_err.error_mechanism._ear.EAR object at 0x7f992998e8f0>], 'brewery_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8d720>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8ec80>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8dae0>, <tab_err.error_mechanism._ear.EAR object at 0x7f992998f2e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f992998fe20>, <tab_err.error_mechanism._ear.EAR object at 0x7f992998f760>, <tab_err.error_mechanism._ear.EAR object at 0x7f992998f7f0>], 'state': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8d720>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8ec80>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f430>, <tab_err.error_mechanism._ear.EAR object at 0x7f992998f8e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cbbb0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c9570>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c9ff0>], 'arbitrary_date': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8d720>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8ec80>, <tab_err.error_mechanism._ear.EAR object at 0x7f992998e800>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cb2b0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cb580>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cb100>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c8ca0>]}
# Column-num_models dict:  {'beer_name': 35, 'style': 35, 'abv': 28, 'brewery_name': 35, 'state': 35, 'arbitrary_date': 21}
# Column-error_rates dict:  {'beer_name': 0.02142857142857143, 'style': 0.02142857142857143, 'abv': 0.026785714285714284, 'brewery_name': 0.02142857142857143, 'state': 0.02142857142857143, 'arbitrary_date': 0.03571428571428571}
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.extraneous_value_template is not set. Choosing a random string augmentation.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: The 'replace_what' parameter is not configured, defaulting to a random character from the given series. Replacements are not guaranteed.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.add_delta_value is none, sampling a random delta value uniformly from the range of column: abv.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: No scaling function was supplied for WrongUnit, defaulting to multiplication by 10.0.
#   return self._apply(data, error_mask, column)
#                   original  ...     error_mask
#                  beer_name  ... arbitrary_date
# 0                 Pub Beer  ...           True
# 1              Devil's Cup  ...           True
# 2      Rise of the Phoenix  ...           True
# 3                 Sinister  ...           True
# 4            Sex and Candy  ...           True
# ...                    ...  ...            ...
# 2405             Belgorado  ...           True
# 2406         Rail Yard Ale  ...           True
# 2407       B3K Black Lager  ...          False
# 2408   Silverback Pale Ale  ...           True
# 2409  Rail Yard Ale (2009)  ...           True
#
# [2410 rows x 18 columns]

# %% [markdown]
# ### Test of include/exlcude error types

# %%
# both error type spec -- should throw error -- Good!
#df_dirty, error_mask = high_level.create_errors(df_clean, max_error_rate=0.75, error_types_to_exclude=[error_type.AddDelta()], error_types_to_include=[error_type.AddDelta()])
#show_result(df_clean, df_dirty, error_mask)

# %%
# Error types to exclude - well formed
df_dirty, error_mask = high_level.create_errors(df_clean, max_error_rate=0.75, error_types_to_exclude=[error_type.MissingValue()])
show_result(df_clean, df_dirty, error_mask)
# Out:
# Column-type dict:  {'beer_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f99294ac9a0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f99294addb0>, <tab_err.error_type._replace.Replace object at 0x7f99294ad0c0>, <tab_err.error_type._typo.Typo object at 0x7f99294ac2b0>], 'style': [<tab_err.error_type._extraneous.Extraneous object at 0x7f99294ac9a0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f99294addb0>, <tab_err.error_type._replace.Replace object at 0x7f99294ad0c0>, <tab_err.error_type._typo.Typo object at 0x7f99294ac2b0>], 'abv': [<tab_err.error_type._add_delta.AddDelta object at 0x7f99294ac5b0>, <tab_err.error_type._outlier.Outlier object at 0x7f99294af850>, <tab_err.error_type._wrong_unit.WrongUnit object at 0x7f99294aef80>], 'brewery_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f99294ac9a0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f99294addb0>, <tab_err.error_type._replace.Replace object at 0x7f99294ad0c0>, <tab_err.error_type._typo.Typo object at 0x7f99294ac2b0>], 'state': [<tab_err.error_type._extraneous.Extraneous object at 0x7f99294ac9a0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f99294addb0>, <tab_err.error_type._replace.Replace object at 0x7f99294ad0c0>, <tab_err.error_type._typo.Typo object at 0x7f99294ac2b0>], 'arbitrary_date': [<tab_err.error_type._add_delta.AddDelta object at 0x7f99294ac5b0>, <tab_err.error_type._outlier.Outlier object at 0x7f99294af850>]}
# Column-mech dict:  {'beer_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99294ad060>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99294af8e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cace0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c8610>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299ca1a0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cada0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c97b0>], 'style': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99294ad060>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99294af8e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c97e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c9a80>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299ca920>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cad40>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8cac0>], 'abv': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99294ad060>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99294af8e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c9570>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8dde0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f3d0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8cd30>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e530>], 'brewery_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99294ad060>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99294af8e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cae60>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8dc90>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8dea0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8df30>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8d390>], 'state': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99294ad060>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99294af8e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e950>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8eef0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f5b0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8d810>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8fdc0>], 'arbitrary_date': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99294ad060>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99294af8e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e5f0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8cdc0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8c310>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8c370>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8cfa0>]}
# Column-num_models dict:  {'beer_name': 28, 'style': 28, 'abv': 21, 'brewery_name': 28, 'state': 28, 'arbitrary_date': 14}
# Column-error_rates dict:  {'beer_name': 0.026785714285714284, 'style': 0.026785714285714284, 'abv': 0.03571428571428571, 'brewery_name': 0.026785714285714284, 'state': 0.026785714285714284, 'arbitrary_date': 0.05357142857142857}
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.extraneous_value_template is not set. Choosing a random string augmentation.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: The 'replace_what' parameter is not configured, defaulting to a random character from the given series. Replacements are not guaranteed.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.add_delta_value is none, sampling a random delta value uniformly from the range of column: abv.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: No scaling function was supplied for WrongUnit, defaulting to multiplication by 10.0.
#   return self._apply(data, error_mask, column)
#                   original  ...     error_mask
#                  beer_name  ... arbitrary_date
# 0                 Pub Beer  ...          False
# 1              Devil's Cup  ...          False
# 2      Rise of the Phoenix  ...           True
# 3                 Sinister  ...           True
# 4            Sex and Candy  ...           True
# ...                    ...  ...            ...
# 2405             Belgorado  ...           True
# 2406         Rail Yard Ale  ...           True
# 2407       B3K Black Lager  ...           True
# 2408   Silverback Pale Ale  ...          False
# 2409  Rail Yard Ale (2009)  ...           True
#
# [2410 rows x 18 columns]

# %%
# error types to include - well formed
df_dirty, error_mask = high_level.create_errors(df_clean, max_error_rate=0.75, error_types_to_include=[error_type.AddDelta()])
show_result(df_clean, df_dirty, error_mask)
# Out:
# Column-type dict:  {'beer_name': [], 'style': [], 'abv': [<tab_err.error_type._add_delta.AddDelta object at 0x7f99294722c0>], 'brewery_name': [], 'state': [], 'arbitrary_date': [<tab_err.error_type._add_delta.AddDelta object at 0x7f99294722c0>]}
# Column-mech dict:  {'beer_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299ca560>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc10>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299ca4d0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cb2b0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cb100>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c9630>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c9ae0>], 'style': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299ca560>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc10>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cbd00>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cacb0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cba90>, <tab_err.error_mechanism._ear.EAR object at 0x7f99292e7ee0>, <tab_err.error_mechanism._ear.EAR object at 0x7f99292bf460>], 'abv': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299ca560>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc10>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299c9b40>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8c1f0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8dd50>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8d6f0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f040>], 'brewery_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299ca560>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc10>, <tab_err.error_mechanism._ear.EAR object at 0x7f99299cb070>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f580>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f5e0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e050>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8e3e0>], 'state': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299ca560>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc10>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8cd90>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8eec0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8c550>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f6d0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8ea10>], 'arbitrary_date': [<tab_err.error_mechanism._enar.ENAR object at 0x7f99299ca560>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f99299cbc10>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8ed70>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8d690>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8dff0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8faf0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8ca60>]}
# Column-num_models dict:  {'beer_name': 0, 'style': 0, 'abv': 7, 'brewery_name': 0, 'state': 0, 'arbitrary_date': 7}
# Column-error_rates dict:  {'abv': 0.10714285714285714, 'arbitrary_date': 0.10714285714285714}
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/high_level.py:199: UserWarning: The column beer_name has no valid error models. 0 errors will be introduced to this column
#   # Build MidLevel Config
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/high_level.py:199: UserWarning: The column style has no valid error models. 0 errors will be introduced to this column
#   # Build MidLevel Config
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/high_level.py:199: UserWarning: The column brewery_name has no valid error models. 0 errors will be introduced to this column
#   # Build MidLevel Config
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/api/high_level.py:199: UserWarning: The column state has no valid error models. 0 errors will be introduced to this column
#   # Build MidLevel Config
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.add_delta_value is none, sampling a random delta value uniformly from the range of column: abv.
#   return self._apply(data, error_mask, column)
#                   original  ...     error_mask
#                  beer_name  ... arbitrary_date
# 0                 Pub Beer  ...           True
# 1              Devil's Cup  ...          False
# 2      Rise of the Phoenix  ...          False
# 3                 Sinister  ...           True
# 4            Sex and Candy  ...           True
# ...                    ...  ...            ...
# 2405             Belgorado  ...          False
# 2406         Rail Yard Ale  ...           True
# 2407       B3K Black Lager  ...           True
# 2408   Silverback Pale Ale  ...           True
# 2409  Rail Yard Ale (2009)  ...           True
#
# [2410 rows x 18 columns]

# %%
# Error rates to include - malformed -- Should throw an error - Works
# df_dirty, error_mask = high_level.create_errors(df_clean, max_error_rate=0.75, error_types_to_include=[])
# show_result(df_clean, df_dirty, error_mask)

# %%
print("Overall Error Rate", error_mask.mean(axis=None), "\n\nColumn-Wise Error Rates:")
error_mask.mean(axis=0)
# Out:
# Overall Error Rate 0.24979253112033195
#
# Column-Wise Error Rates:
# beer_name         0.000000
# style             0.000000
# abv               0.749378
# brewery_name      0.000000
# state             0.000000
# arbitrary_date    0.749378
# dtype: float64

# %% [markdown]
# ### Test of the include/exclude error mechanisms

# %%
df_dirty, error_mask = high_level.create_errors(df_clean, max_error_rate=0.75, error_mechs_to_exclude=[error_mechanism.EAR()])
show_result(df_clean, df_dirty, error_mask)
# Out:
# Column-type dict:  {'beer_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8f8e0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8c610>, <tab_err.error_type._replace.Replace object at 0x7f9928f8d0c0>, <tab_err.error_type._typo.Typo object at 0x7f9928f8df60>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8ed10>], 'style': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8f8e0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8c610>, <tab_err.error_type._replace.Replace object at 0x7f9928f8d0c0>, <tab_err.error_type._typo.Typo object at 0x7f9928f8df60>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8ed10>], 'abv': [<tab_err.error_type._add_delta.AddDelta object at 0x7f9928f8fac0>, <tab_err.error_type._outlier.Outlier object at 0x7f9928f8d8a0>, <tab_err.error_type._wrong_unit.WrongUnit object at 0x7f9928f8ece0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8ed10>], 'brewery_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8f8e0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8c610>, <tab_err.error_type._replace.Replace object at 0x7f9928f8d0c0>, <tab_err.error_type._typo.Typo object at 0x7f9928f8df60>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8ed10>], 'state': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8f8e0>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8c610>, <tab_err.error_type._replace.Replace object at 0x7f9928f8d0c0>, <tab_err.error_type._typo.Typo object at 0x7f9928f8df60>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8ed10>], 'arbitrary_date': [<tab_err.error_type._add_delta.AddDelta object at 0x7f9928f8fac0>, <tab_err.error_type._outlier.Outlier object at 0x7f9928f8d8a0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928f8ed10>]}
# Column-mech dict:  {'beer_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8e770>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8dcf0>], 'style': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8e770>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8dcf0>], 'abv': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8e770>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8dcf0>], 'brewery_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8e770>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8dcf0>], 'state': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8e770>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8dcf0>], 'arbitrary_date': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8e770>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8dcf0>]}
# Column-num_models dict:  {'beer_name': 10, 'style': 10, 'abv': 8, 'brewery_name': 10, 'state': 10, 'arbitrary_date': 6}
# Column-error_rates dict:  {'beer_name': 0.075, 'style': 0.075, 'abv': 0.09375, 'brewery_name': 0.075, 'state': 0.075, 'arbitrary_date': 0.125}
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.extraneous_value_template is not set. Choosing a random string augmentation.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: The 'replace_what' parameter is not configured, defaulting to a random character from the given series. Replacements are not guaranteed.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.add_delta_value is none, sampling a random delta value uniformly from the range of column: abv.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: No scaling function was supplied for WrongUnit, defaulting to multiplication by 10.0.
#   return self._apply(data, error_mask, column)
#                   original                                  ... error_mask
#                  beer_name                           style  ...      state arbitrary_date
# 0                 Pub Beer             American Pale Lager  ...       True          False
# 1              Devil's Cup         American Pale Ale (APA)  ...       True          False
# 2      Rise of the Phoenix                    American IPA  ...       True          False
# 3                 Sinister  American Double / Imperial IPA  ...       True           True
# 4            Sex and Candy                    American IPA  ...       True           True
# ...                    ...                             ...  ...        ...            ...
# 2405             Belgorado                     Belgian IPA  ...       True           True
# 2406         Rail Yard Ale        American Amber / Red Ale  ...       True           True
# 2407       B3K Black Lager                     Schwarzbier  ...       True           True
# 2408   Silverback Pale Ale         American Pale Ale (APA)  ...       True           True
# 2409  Rail Yard Ale (2009)        American Amber / Red Ale  ...       True           True
#
# [2410 rows x 18 columns]

# %% [markdown]
# ### Test of random seed

# %%
df_dirty, error_mask = high_level.create_errors(df_clean, max_error_rate=0.75, seed=10)
show_result(df_clean, df_dirty, error_mask)
# Out:
# Column-type dict:  {'beer_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8d690>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8e7a0>, <tab_err.error_type._replace.Replace object at 0x7f9928f8faf0>, <tab_err.error_type._typo.Typo object at 0x7f9928a906a0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928a93220>], 'style': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8d690>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8e7a0>, <tab_err.error_type._replace.Replace object at 0x7f9928f8faf0>, <tab_err.error_type._typo.Typo object at 0x7f9928a906a0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928a93220>], 'abv': [<tab_err.error_type._add_delta.AddDelta object at 0x7f9928f8c340>, <tab_err.error_type._outlier.Outlier object at 0x7f9928f8e6e0>, <tab_err.error_type._wrong_unit.WrongUnit object at 0x7f9928a900d0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928a93220>], 'brewery_name': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8d690>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8e7a0>, <tab_err.error_type._replace.Replace object at 0x7f9928f8faf0>, <tab_err.error_type._typo.Typo object at 0x7f9928a906a0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928a93220>], 'state': [<tab_err.error_type._extraneous.Extraneous object at 0x7f9928f8d690>, <tab_err.error_type._mojibake.Mojibake object at 0x7f9928f8e7a0>, <tab_err.error_type._replace.Replace object at 0x7f9928f8faf0>, <tab_err.error_type._typo.Typo object at 0x7f9928a906a0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928a93220>], 'arbitrary_date': [<tab_err.error_type._add_delta.AddDelta object at 0x7f9928f8c340>, <tab_err.error_type._outlier.Outlier object at 0x7f9928f8e6e0>, <tab_err.error_type._missing.MissingValue object at 0x7f9928a93220>]}
# Column-mech dict:  {'beer_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8fd30>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8d930>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928f8f160>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a904f0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92620>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a921a0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92860>], 'style': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8fd30>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8d930>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a90c70>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a91150>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a901c0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a91090>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a93b80>], 'abv': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8fd30>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8d930>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92da0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a924d0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92350>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a93160>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a90760>], 'brewery_name': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8fd30>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8d930>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92710>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a91780>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a90190>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92e60>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a90310>], 'state': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8fd30>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8d930>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a90c10>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92e90>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a90040>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a93820>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a93910>], 'arbitrary_date': [<tab_err.error_mechanism._enar.ENAR object at 0x7f9928f8fd30>, <tab_err.error_mechanism._ecar.ECAR object at 0x7f9928f8d930>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a921d0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92bf0>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92290>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a91450>, <tab_err.error_mechanism._ear.EAR object at 0x7f9928a92ce0>]}
# Column-num_models dict:  {'beer_name': 35, 'style': 35, 'abv': 28, 'brewery_name': 35, 'state': 35, 'arbitrary_date': 21}
# Column-error_rates dict:  {'beer_name': 0.02142857142857143, 'style': 0.02142857142857143, 'abv': 0.026785714285714284, 'brewery_name': 0.02142857142857143, 'state': 0.02142857142857143, 'arbitrary_date': 0.03571428571428571}
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.extraneous_value_template is not set. Choosing a random string augmentation.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: The 'replace_what' parameter is not configured, defaulting to a random character from the given series. Replacements are not guaranteed.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: self.config.add_delta_value is none, sampling a random delta value uniformly from the range of column: abv.
#   return self._apply(data, error_mask, column)
# /mnt/c/Users/njcha/OneDrive/BHT/Research/tab_err/tab_err/error_type/_error_type.py:67: UserWarning: No scaling function was supplied for WrongUnit, defaulting to multiplication by 10.0.
#   return self._apply(data, error_mask, column)
#                   original  ...     error_mask
#                  beer_name  ... arbitrary_date
# 0                 Pub Beer  ...           True
# 1              Devil's Cup  ...           True
# 2      Rise of the Phoenix  ...           True
# 3                 Sinister  ...           True
# 4            Sex and Candy  ...           True
# ...                    ...  ...            ...
# 2405             Belgorado  ...           True
# 2406         Rail Yard Ale  ...           True
# 2407       B3K Black Lager  ...           True
# 2408   Silverback Pale Ale  ...           True
# 2409  Rail Yard Ale (2009)  ...           True
#
# [2410 rows x 18 columns]
